# %% [markdown]
# # EduTrack - Catalog & schema setup

# %%
# %sql
CREATE CATALOG IF NOT EXISTS edutrack;

# %%
# %sql
USE CATALOG edutrack;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS edutrack.bronze;
CREATE SCHEMA IF NOT EXISTS edutrack.silver;
CREATE SCHEMA IF NOT EXISTS edutrack.gold;

# %%
# %sql
SHOW DATABASES FROM edutrack;

# %%
dbutils.fs.ls('/Volumes/edutrack/source_data/raw/')
